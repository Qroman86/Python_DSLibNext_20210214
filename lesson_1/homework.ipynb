# %%
import numpy as np
import pandas as pd
from numpy import NaN

TRAIN_CSV_PATH = 'train.csv'
df = pd.read_csv(TRAIN_CSV_PATH)
df.head()
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0       Own Home       482087.0                  NaN        0.0
# 1       Own Home      1025487.0            10+ years        0.0
# 2  Home Mortgage       751412.0              8 years        0.0
# 3       Own Home       805068.0              6 years        0.0
# 4           Rent       776264.0              8 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                     11.0                     26.3             685960.0
# 1                     15.0                     15.3            1181730.0
# 2                     11.0                     35.0            1182434.0
# 3                      8.0                     22.5             147400.0
# 4                     13.0                     13.6             385836.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# ...

# %%
df.iloc[0]
# Out:
# Home Ownership                            Own Home
# Annual Income                               482087
# Years in current job                           NaN
# Tax Liens                                        0
# Number of Open Accounts                         11
# Years of Credit History                       26.3
# Maximum Open Credit                         685960
# Number of Credit Problems                        1
# Months since last delinquent                   NaN
# Bankruptcies                                     1
# Purpose                         debt consolidation
# Term                                    Short Term
# Current Loan Amount                          1e+08
# Current Credit Balance                       47386
# Monthly Debt                                  7914
# Credit Score                                   749
# Credit Default                                   0
# Name: 0, dtype: object

# %%
df.shape
# Out:
# (7500, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Home Ownership                7500 non-null   object
#  1   Annual Income                 5943 non-null   float64
#  2   Years in current job          7129 non-null   object
#  3   Tax Liens                     7500 non-null   float64
#  4   Number of Open Accounts       7500 non-null   float64
#  5   Years of Credit History       7500 non-null   float64
#  6   Maximum Open Credit           7500 non-null   float64
#  7   Number of Credit Problems     7500 non-null   float64
#  8   Months since last delinquent  3419 non-null   float64
#  9   Bankruptcies                  7486 non-null   float64
#  10  Purpose                       7500 non-null   object
#  11  Term                          7500 non-null   object
# ...

# %%
df.describe()
# Out:
#        Annual Income    Tax Liens  Number of Open Accounts  \
# count   5.943000e+03  7500.000000              7500.000000
# mean    1.366392e+06     0.030133                11.130933
# std     8.453392e+05     0.271604                 4.908924
# min     1.645970e+05     0.000000                 2.000000
# 25%     8.443410e+05     0.000000                 8.000000
# 50%     1.168386e+06     0.000000                10.000000
# 75%     1.640137e+06     0.000000                14.000000
# max     1.014934e+07     7.000000                43.000000
#
#        Years of Credit History  Maximum Open Credit  \
# count              7500.000000         7.500000e+03
# mean                 18.317467         9.451537e+05
# std                   7.041946         1.602622e+07
# min                   4.000000         0.000000e+00
# 25%                  13.500000         2.792295e+05
# 50%                  17.000000         4.781590e+05
# 75%                  21.800000         7.935015e+05
# ...

# %%
df['Credit Default'].value_counts()
# Out:
# 0    5387
# 1    2113
# Name: Credit Default, dtype: int64

# %%
#Задание №1
#Посчитать основные статистики по каждому признаку (минимальные, максимальные, средние значения). 
#Сделать выводы об адекватности этих статистик.

#Home Ownership - домовладение
#Принимает строковые значения - например "Own Home" Можно свести к категориям

#Annual Income - годовой доход
#Принимает числовые значения  min 1.645970e+05 mean 1.366392e+06 max 1.014934e+07 - выглядит правдоподобно

#Years in current job - количество лет на текущем месте работы
#Принимает строковые значения вида 8 years По всей видимости можно привести к числовым значениям

#Tax Liens - налоговые обременения
#Не очень понятен контект данного признака.
#Принимает числовые значения. Статистики следующие min 0.000000 mean 0.030133 max 7.000000
#Можно предположить что максимальное значение 7.000000 - это выброс, но наверняка утверждать невозможно

#Number of Open Accounts - количество открытых счетов
#Принимает числовые значения. min 2.000000	 mean 11.130933 max 43.000000 - выглядит правдоподобно. Удивительно, что минимум открытых
#счетов принимает значение 2

#Years of Credit History - количество лет кредитной истории
#Принимает числовые значения min 4.000000	 mean 18.317467 max 57.700000. 
#Странно что минимум количеств лет кредитной истории равен 4


#Maximum Open Credit - наибольший открытый кредит
#Принимает числовые значения min 0.000000e+00 mean 9.451537e+05 max 1.304726e+09 
#максимальное значение на четеры порядка превосходит среднее и медиану, это выглядит немного странно

#Number of Credit Problems - количество проблем с кредитом
#Принимает числовые значения min 0.000000 mean 0.170000 max 7.000000
#Слишком много людей имевших слишком мало проблем с кредитом (среднее 0.170000 при максимуме в 7)

#Months since last delinquent - количество месяцев с последней просрочки платежа
#min 0.000000 mean 34.692600 max 118.000000 значения выглядят правдоподобно


#Bankruptcies - банкротства
#min 0.000000 mean 0.117152 max 4.000000 - среднее количество банкроств 0.117152 при максимуме в 4
#это выглядит слишком хорошо

#Purpose - цель кредита
#строковое значение - можно перевести в категорию

#Term - срок кредита
#строковое значение - можно оперировать только категориями

#Current Loan Amount - текущая сумма кредита
#min 1.124200e+04	 mean 1.187318e+07	 max 1.000000e+08 
#средняя только на порядок меньше максимума

#Current Credit Balance - текущий кредитный баланс
#min 0.000000e+00	 mean 2.898332e+05 max 6.506797e+06
#признак выглядит адекватным

#Monthly Debt - ежемесячный долг
#min 0.000000 mean 18314.454133 max 136679.000000
#признак выглядит адекватным

#Credit Score - баллы кредитного рейтинга
#min 585.000000 mean 1151.087498 max 7510.000000
# разброс пределах двух порядков. признак выглядит адекватным


#Credit Default - факт невыполнения кредитных обязательств (0 - погашен вовремя, 1 - просрочка)
#Целевой признак, поэтому среднее здесь бессмысленно оценивать min 0 max 1 -все в пределах нормы

# %%
df.describe()
# Out:
#        Annual Income    Tax Liens  Number of Open Accounts  \
# count   5.943000e+03  7500.000000              7500.000000
# mean    1.366392e+06     0.030133                11.130933
# std     8.453392e+05     0.271604                 4.908924
# min     1.645970e+05     0.000000                 2.000000
# 25%     8.443410e+05     0.000000                 8.000000
# 50%     1.168386e+06     0.000000                10.000000
# 75%     1.640137e+06     0.000000                14.000000
# max     1.014934e+07     7.000000                43.000000
#
#        Years of Credit History  Maximum Open Credit  \
# count              7500.000000         7.500000e+03
# mean                 18.317467         9.451537e+05
# std                   7.041946         1.602622e+07
# min                   4.000000         0.000000e+00
# 25%                  13.500000         2.792295e+05
# 50%                  17.000000         4.781590e+05
# 75%                  21.800000         7.935015e+05
# ...

# %%
#Задание 2.Посчитать для каждого признака, сколько в нем уникальных значений и как часто они встречаются. 
#Сделать выводы по каждому признаку.

for cat_colname in df.columns:
    print(str(cat_colname) + '\n\n' + str(df[cat_colname].value_counts()) + '\n' + '*' * 100 + '\n')
# Out:
# Home Ownership
#
# Home Mortgage    3637
# Rent             3204
# Own Home          647
# Have Mortgage      12
# Name: Home Ownership, dtype: int64
# ****************************************************************************************************
#
# Annual Income
#
# 1161660.0    4
# 1058376.0    4
# 1338113.0    4
# 1043651.0    4
# 969475.0     4
#             ..
# 1141254.0    1
# 7907382.0    1
# 1534478.0    1
# 972040.0     1
# 1654786.0    1
# Name: Annual Income, Length: 5478, dtype: int64
# ****************************************************************************************************
#
# Years in current job
#
# 10+ years    2332
# 2 years       705
# 3 years       620
# < 1 year      563
# 5 years       516
# 1 year        504
# 4 years       469
# 6 years       426
# 7 years       396
# 8 years       339
# 9 years       259
# Name: Years in current job, dtype: int64
# ...

# %%
#Home Mortgage:
#Home Mortgage    3637
#Rent             3204
#Own Home          647
#Have Mortgage      12

#Налицо всего четыре категории 90% которых приходится всего на две Home Mortgage и Rent

#Annual Income - здесь количество уникальных значений 5478, что естественно

#Years in current job
#11 категорий, значения по которым распределены неравномерно. Самая популярная 10+ years Наименее популярная 9 years
#стоит отметить пи на 2 years со значением 705

#Tax Liens

#0.0    7366
#1.0      83
#2.0      30
#3.0      10
#4.0       6
#5.0       2
#6.0       2
#7.0       1

#Подавляющее число значений отнесено к значению 0.0 При этом всего 8 уникальных значений. Вполне определенно можно говорить
#о категориях

#Number of Open Accounts
# здесь наравномерный график из нескольких десятков уникальных значений. Стоит отметить что самые популярные 
#значения оказалиь 7,8,9,10 и 11

#Years of Credit History
#408 уникальных значений. То есть приводится не целое а дробное число лет.
#Самое пополулярное значений 15 лет (104 раза)

#Maximum Open Credit
#6963 уникальных значений

#Number of Credit Problems
#0.0    6469
#1.0     882
#2.0      93
#3.0      35
#4.0       9
#5.0       7
#6.0       4
#7.0       1
#подовляющее количество лиц имеет ноль проблем с кредитом либо одну проблему. 8 уникальных значений

#Months since last delinquent
#89 уникальных значений


#Bankruptcies
#0.0    6660
#1.0     786
#2.0      31
#3.0       7
#4.0       2
#Всего пять уникальных значений

#Purpose

#debt consolidation      5944
#other                    665
#home improvements        412
#business loan            129
#buy a car                 96
#medical bills             71
#major purchase            40
#take a trip               37
#buy house                 34
#small business            26
#wedding                   15
#moving                    11
#educational expenses      10
#vacation                   8
#renewable energy           2

#15 уникальных значений

#Term
#Short Term    5556
#Long Term     1944
#Всего 2 уникальных значения

#Current Loan Amount
#5386 уникальных значения из которых 879 приходится на 99999999.0 

#Current Credit Balance
#6592 уникальных значений, что естественно для такого признака

#Monthly Debt
#6716 уникальных значений, что естественно для такого признака


#Credit Score
#268 уникальных значений, то есть это говорит о том что есть вполне узкий диапазон, в котором укладывается 
#данный признак по отношению к количеству рассматриваемых лиц
#У кого-то кредитный рейтинг 7010

#Credit Default
#0    5387
#1    2113
#Целевой признак. Значения строго либо 0 либо 1 при этом есть существенный более чем в два раза перевес
#значений для уникального значения "0"

# %%
#Залание3.Используя выводы из двух предыдущих заданий, найдите те наблюдения, где есть пропуски, выбросы 
#(неадекватные значения признака, которые отличаются от большинства), используя фильтрацию из pandas.


df.isna().sum()
# Out:
# Home Ownership                     0
# Annual Income                   1557
# Years in current job             371
# Tax Liens                          0
# Number of Open Accounts            0
# Years of Credit History            0
# Maximum Open Credit                0
# Number of Credit Problems          0
# Months since last delinquent    4081
# Bankruptcies                      14
# Purpose                            0
# Term                               0
# Current Loan Amount                0
# Current Credit Balance             0
# Monthly Debt                       0
# Credit Score                    1557
# Credit Default                     0
# dtype: int64

# %%
#Довольно много пропусков для Annual Income, Years in current job, Months since last delinquent, Bankruptcies, Credit Score
df.loc[df['Maximum Open Credit'] > 100000000]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 44    Have Mortgage      1334256.0            10+ years        0.0
# 617   Home Mortgage            NaN              3 years        0.0
# 2617  Home Mortgage      3217802.0            10+ years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 44                       17.0                     15.4         3.800523e+08
# 617                      13.0                     27.5         1.304726e+09
# 2617                     12.0                     35.5         2.655129e+08
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 44                          1.0                          35.0           0.0
# 617                         0.0                           NaN           0.0
# 2617                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# ...

# %%
df.loc[df['Tax Liens'] > 3]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 1129           Rent      1691019.0              5 years        4.0
# 1214           Rent      3061584.0              2 years        6.0
# 2716  Home Mortgage      2522611.0            10+ years        5.0
# 3028           Rent            NaN                  NaN        4.0
# 3435           Rent      1231561.0            10+ years        5.0
# 3814           Rent      1254513.0               1 year        4.0
# 4122  Home Mortgage      3297412.0             < 1 year        4.0
# 4774       Own Home      1268896.0                  NaN        4.0
# 5373       Own Home      1711881.0            10+ years        6.0
# 5969           Rent      2897310.0            10+ years        7.0
# 6907       Own Home            NaN              7 years        4.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 1129                     11.0                     20.4             681934.0
# ...

# %%
df.loc[df['Number of Credit Problems'] == 7]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 5969           Rent      2897310.0            10+ years        7.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 5969                      9.0                     20.0             434126.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 5969                        7.0                          54.0           0.0
#
#             Purpose        Term  Current Loan Amount  Current Credit Balance  \
# 5969  medical bills  Short Term             782782.0                275576.0
#
#       Monthly Debt  Credit Score  Credit Default
# 5969       37182.0         716.0               0

# %%
df.loc[df['Bankruptcies'] == 4]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 4223           Rent       918517.0            10+ years        0.0
# 5788           Rent      3034224.0              3 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 4223                      3.0                     19.8              81070.0
# 5788                     10.0                     16.7             307582.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 4223                        4.0                          78.0           4.0
# 5788                        4.0                           NaN           4.0
#
#                  Purpose        Term  Current Loan Amount  \
# 4223  debt consolidation  Short Term              74888.0
# 5788  debt consolidation   Long Term             418858.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# ...

# %%
df.loc[df['Annual Income'].isna()]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 5              Rent            NaN              7 years        0.0
# 8     Home Mortgage            NaN              5 years        0.0
# 9     Home Mortgage            NaN               1 year        0.0
# 10    Home Mortgage            NaN             < 1 year        0.0
# 16             Rent            NaN              7 years        0.0
# ...             ...            ...                  ...        ...
# 7482  Home Mortgage            NaN            10+ years        0.0
# 7492  Home Mortgage            NaN            10+ years        0.0
# 7494       Own Home            NaN             < 1 year        0.0
# 7498  Home Mortgage            NaN                  NaN        0.0
# 7499           Rent            NaN              4 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 5                        12.0                     14.6             366784.0
# ...

# %%
df.loc[df['Purpose'] == 'renewable energy']
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 2223  Home Mortgage            NaN            10+ years        0.0
# 7082       Own Home            NaN              3 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 2223                      3.0                     22.6             295218.0
# 7082                     14.0                     27.9             182094.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 2223                        0.0                           NaN           0.0
# 7082                        0.0                          25.0           0.0
#
#                Purpose        Term  Current Loan Amount  \
# 2223  renewable energy   Long Term             215468.0
# 7082  renewable energy  Short Term              21912.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# ...

# %%
df.loc[df['Credit Score'] == 7010]
# Out:
#    Home Ownership  Annual Income Years in current job  Tax Liens  \
# 94           Rent      1049294.0              3 years        0.0
#
#     Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 94                      5.0                      6.1             249810.0
#
#     Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 94                        0.0                           NaN           0.0
#
#           Purpose        Term  Current Loan Amount  Current Credit Balance  \
# 94  business loan  Short Term             337502.0                119529.0
#
#     Monthly Debt  Credit Score  Credit Default
# 94       15215.0        7010.0               1

# %%
df.loc[df['Credit Score'] > 7010]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 87    Home Mortgage      1533566.0              7 years        0.0
# 96             Rent       757568.0              5 years        0.0
# 116   Home Mortgage      1039984.0                  NaN        0.0
# 152   Home Mortgage      1026817.0            10+ years        0.0
# 153            Rent       749816.0              9 years        0.0
# ...             ...            ...                  ...        ...
# 7364           Rent       680162.0              5 years        0.0
# 7379       Own Home       290415.0             < 1 year        0.0
# 7450  Home Mortgage      1432277.0            10+ years        0.0
# 7460           Rent       769462.0              5 years        0.0
# 7496  Home Mortgage      1533984.0               1 year        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 87                       11.0                     14.8             715462.0
# ...
